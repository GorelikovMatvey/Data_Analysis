# %% [markdown]
# # Результат ревью:
#
# Я отмечаю адекватный уровень твоей программистской подготовки. Ты используешь продвинутые концепции языка Python, библиотеки pandas и одной из основных библиотек машинного обучения sckit-learn. Это показывает твой уровень владения инструментами анализа данных и machine learning.
#
# С комментированием никаких проблем нет. Твоих объяснений достаточно для понимания твоими коллегами хода мыслей. Ссылки из брифа проекта в нужных местах также помогают следовать за развитием событий и дают полную информацию касаемо того, что будет происходить в том или ином разделе проекта.
#
# Мне было просто проверять твой проект, потому что он чётко структурирован, с использованием оглавления.
#
# Зелёным цветом я отметил и прокомментировал удачные и элегантные решения, на которые ты можешь опираться в будущих проектах.
#
# Жёлтым цветом я выделил то, что в следующий раз можно сделать по-другому. Ты можешь учесть эти комментарии при выполнении будущих заданий или доработать проект сейчас.
#
# Красных комментариев, которые бы не позволяли мне принять твой проект в его нынешнем состоянии - нет.
#
# ПРОЕКТ ПРИНЯТ!
#
# Подводя итог: отличная работа, молодец! Желаю тебе успехов в учёбе, желаю, чтобы проекты сдавались или сразу, или после первой итерации! Удачи!
#
# Если же после факта принятия проекта у тебя возникнут дополнительные вопросы – я никуда не пропал. Мой адрес эл/почты: anepomnjashiy@gmail.com, имя в Пачке: anepomnjashiy, имя в Телеграмме: https://t.me/aleks_nep
#
# p.s. я тебе на твой адрес эл/почты сейчас вышлю некоторые материалы из своей электронной библиотеки - надеюсь они будут тебе полезными в учёбе.</div>

# %% [markdown]
# Приветствую Матвей!
#
# Меня зовут Александр Непомнящий и я буду проверять твой проект. Предлагаю общаться на «ты» :))) Но, если это не удобно - мы вполне можем перейти на вы".
#
# Вкратце обо мне: я работаю в сфере информационных технологий, аналитика (анализ) данных - это и мой рабочий функционал и личная, интересная мне область для саморазвития. Используемый стек: python, pandas, графические библиотеки matplotlib/seaborn/plotly. Сфера применения: маркетинговая аналитика в медицинской клинике (Клиника «Кивач», www.kivach.ru, республика Карелия). Если вдруг есть вопрос – что делает аналитик в коммерческой медицине – то вот короткий ответ. Самый главный вопрос, на который мы хотим получить ответ (и который в дальнейшем приведёт к перераспределению рекламного бюджета, плюс напрямую повлияет на разработку и предложению рынку новых лечебных программ) - это КТО ОН, НАШ КЛИЕНТ? Фактически это задача (на нашем внутреннем языке формулируется как построение и анализ «ПОРТРЕТА КЛИЕНТА»). Визуализируем и пытаемся придать смысл половозрастным данным наших клиентов, кто из какого региона и в какие времена года к нам приезжает. Учитываем количество приездов. Учитываем на какую программу этот конкретный клиент приехал в первый раз и как в дальнейшем меняются его предпочтения. Пытаемся построить модель оттока и спрогнозировать, когда клиент уйдёт в отток. Смотрим цифры (суммы трат клиентов на отдельных группах медицинских программ). Анализируем медицинские услуги, которые входят в путёвку, а также что, в каких количествах и на какую сумму клиент покупает дополнительно. Очень вкратце как-то так.
#
# Теперь к сути: основная цель моей проверки - пройти по шагам, по логике твоего решения и обсудить те моменты, которые можно изменить, улучшить, довести до идеала. Такой формат работы двух программистов (аналитиков) ты или уже встречал(а), или встретишь на своей новой работе. Кто-то такой процесс называет "код-ревью", ну а как по мне, так это обмен опытом двух коллег, когда каждый из нас становиться лучше в процессе дискуссии.
#
# Свои мысли, советы, комментарии и вопросы я буду оставлять в текстовых ячейках (markdown) ПОД твоим кодом.
# Для твоего удобства все эти заметки будут "цветными", как на примерах ниже:
#
# "Зелеными" комментариями я буду отмечать твой элегантный ("красивый") код и/или удачные решения, на которые ты можешь смело опираться в будущих проектах.
# <div class="alert alert-success">
# <b>Отлично! 👍</b>
#
# Отличная находка, элегантный код ...</div>
#
# "Жёлтые" комментарии - это мои размышления, предложения, что-то, что на следующей итерации можно сделать по-другому. Твоя реакция на "жёлтые" комментарий необходима и подразумевает или правки, или реакцию или аргументированное согласие/не согласие. Я искренне верю, что наш двусторонний диалог под "желтым" комментарием - это то, от чего твой проект только выиграет. <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Здесь я бы предложил использовать .... Мои аргументы в пользу этого ...</div>
#
# "Красные" комментарий будут появляться, когда что-то пойдёт не так: например, код будет выдавать ошибку. Или, когда в проекте не будет ответов на основные вопросы, ради которых весь анализ и выполнялся. "Красные" комментарии необходимо будет исправить, прежде чем я смогу принять проект.
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# В этой ячейке код работает не так как задумано ...</div>
#
# Пожалуйста, не перемещай, не изменяй и не удаляй мои комментарии. Это поможет мне оперативно выполнить повторную проверку твоего проекта.
#
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте по моим рекомендациям — пиши об этом, лучше всего в новой ячейке, сразу под моим комментарием. Если для своих комментариев ты будешь использовать какой-то заметный цвет, то мне будет легче отследить твои изменения, например так:
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Текст твоего комментария ...</font>
# </div>
#
# **Распространенные типичные недочёты в проектах студентов:**
#
# <div class="alert alert-danger" ❌>
# Неработоспособный код. Проверь проект на работоспособность перед отправкой на проверку. Это важный навык, который тебе пригодится как на собеседовании, при выполнении тестового задания, так и перед совещанием у руководства компании.</div>
# <div class="alert alert-danger" ❌>
# Проект не структурирован. В проекте должна быть структура, т.е. названия разделов и подразделов должны быть записаны в ячейках Markdown.</div>
# <div class="alert alert-warning" 👉 >
# Отсутствие описания, целей проекта, его задач, выводов. В описании должны быть озвучены поставленные задачи, содержание датасета, промежуточные и финальные выводы. Как правило, заказчик читает только финальный вывод, поэтому важно добавить информацию о проведенном исследовании, применить форматирование текста, в общем, сделать красиво, чтобы было понятно, что проведено настоящее исследование и выводу можно верить.</div>
# <div class="alert alert-warning" 👉 >
# "Длинный код". Код и и комментарии, которые прячутся за правым концом ячейки нужно переносить на новую строку. Твои будущие коллеги не оценят необходимость постоянного скроллинга. Согласно PEP8: https://www.python.org/dev/peps/pep-0008/ длина строки не должна превышать 79 символов.</div>
# <div class="alert alert-warning" 👉 >
# Твои коллеги ценят и твое и своё время, поэтому "подсвечивай" свои комментарии в ячейках Markdown. Подробнее про синтаксис Markdown, с примерами, можно почитать здесь: https://paulradzkov.com/2014/markdown_cheatsheet/?
# </div>

# %% [markdown]
# # Сборный проект №1.
#
# Вы работаете в интернет-магазине «Стримчик», который продаёт по всему миру компьютерные игры. Из открытых источников доступны исторические данные о продажах игр, оценки пользователей и экспертов, жанры и платформы (например, Xbox или PlayStation).
#
# **Цель проекта.**
# Необходимо выявить определяющие успешность игры закономерности. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.
#
# **Описание данных:**
#
# Перед вами данные до 2016 года. Представим, что сейчас декабрь 2016 г., и вы планируете кампанию на 2017-й. Нужно отработать принцип работы с данными. Неважно, прогнозируете ли вы продажи на 2017 год по данным 2016-го или же 2027-й — по данным 2026 года.
# В наборе данных попадается аббревиатура ESRB (Entertainment Software Rating Board) — это ассоциация, определяющая возрастной рейтинг компьютерных игр. ESRB оценивает игровой контент и присваивает ему подходящую возрастную категорию, например, «Для взрослых», «Для детей младшего возраста» или «Для подростков».
#
#  - Name — название игры
#  - Platform — платформа
#  - Year_of_Release — год выпуска
#  - Genre — жанр игры
#  - NA_sales — продажи в Северной Америке (миллионы проданных копий)
#  - EU_sales — продажи в Европе (миллионы проданных копий)
#  - JP_sales — продажи в Японии (миллионы проданных копий)
#  - Other_sales — продажи в других странах (миллионы проданных копий)
#  - Critic_Score — оценка критиков (максимум 100)
#  - User_Score — оценка пользователей (максимум 10)
#  - Rating — рейтинг от организации ESRB (англ. Entertainment Software Rating Board). Эта ассоциация определяет рейтинг компьютерных игр и присваивает им подходящую возрастную категорию.

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Ты делаешь хорошую работу уже в начале нашего аналитического проекта. Твой подход к описанию всего проекта уже с самого начала – это плюс. Ты ясно и четко формулируешь цель нашего исследования, что дает нам прочную основу для дальнейших этапов.
#
# Твое описание того, как ты будешь двигаться дальше, также впечатляет. Твои действия по обработке и структурированию данных в начальных этапах – это правильный шаг. Также отмечу, что твое умение систематизировать данные с самого начала проекта позволяет нам лучше понимать характер данных и уже сейчас делать некоторые предварительные наметки. Такой подход в начале аналитического/Дата Сайенс проекта говорит о твоей компетентности и ставит нас на "правильную дорогу" для выполнения успешного исследования.
# </div>

# %% [markdown]
# ### Шаг 1. Загрузка данных и изучение общей информации.

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats as st
from math import sqrt
from scipy.stats import binom, norm

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Отлично, все импорты собраны в начале "тетрадки"!
#
# ---
# В Python есть своя философия. Именно отсюда берутся определенные правила и стандарты. В пайтон такое соглашение назвали PEP8.
#
# Соответствие PEP8 позволяет видеть основную структуру вашего кода другим разработчикам. Не нужно привыкать к другому оформлению кода. Если вы привыкли как-то оформлять код, а увидели что-то совершенно другое, то вы поймете.
#
# Официальная документация: https://peps.python.org/pep-0008/
#
# Основные моменты и рекомендации:
#
# - Используй пробелы, разрешается использование табов, но смешивание запрещено. Отступ соответствует 4 пробелам. Хорошие редакторы кода автоматически заменяют табы на пробелы.
#
# - Вокруг операторов +, -, =, *, /, ** должны быть пробелы.
#
# - Строка не должна превышать 79 символов
#
# - Ну и наконец про импорты: импорты можно делать только по одному на строку! При этом из одного модуля можно доставать несколько нужных объектов. Порядок тоже важен:
#
# - импорты из стандартной библиотеки
# - импорты из сторонних библиотек
# - импорты пользовательских модулей текущего проекта (например если выносишь функции в отдельный модуль)
#
# И нежелательно их перемешивать с константами и переменными.
#
# p.s. состав стандартных библиотек Python здесь: [The Python Standard Library](https://docs.python.org/3/library/)
# </div>

# %% [markdown]
# Импортируем необходимые для работы библиотеки, cчитываем CSV-файл и сохраняем его в датафрейм.

# %%
games  = pd.read_csv('/datasets/games.csv', sep=',')
#games = pd.read_csv(r'C:\Users\Matvey\Desktop\Курс\Проект_5\games.csv', sep=',')
# Увеличим максимальное количество отображающихся столбцов.
pd.set_option('display.max_columns', None)
# Приведем названия столбцов к ниженму регистру.
games.columns = [col.lower().replace(' ','_') for col in games.columns]
games.info()
games.head(5)

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Отлично. Импортировали требуемые для анализа библиотеки и загрузили данные. Сейчас посмотрим на их состояние и если всё ОК, сможем приступать к построению моделей....
#
# p.s. при установке дополнительных библиотек (через ! pip install ...) можно использовать полезный ключ **-q** (он "подавит" служебные сообщения об установке, которых может быть достаточно много - вплоть до нескольких экранов прокрутки)
#
# p.p.s. При считывании данных из файла здорово перестраховывать себя от ошибок, связанных, например, с неверным указанием пути к файлу. А иногда бывает, что работаешь с файлом локально, выгружаешь его на сервер, ожидая, что он будет принимать данные, которые лежат на том же сервере, а код падает с ошибкой, потому что путь к файлу не поменялся с локального на серверный.
#
# Для этого, например, можно использовать конструкцию `try-except`: сначала пробуешь локальный путь, при возникновении ошибки используется серверный путь (подробнее можешь почитать тут: https://pythonworld.ru/tipy-dannyx-v-python/isklyucheniya-v-python-konstrukciya-try-except-dlya-obrabotki-isklyuchenij.html).
#
# Но еще лучше использовать библиотеку `os` - её использование позволит тебе проверять существование указанных директорий (что может быть актуально при одновременной работа на локальном и сетевом окружении) и загружать данные из существующей директории, избегая ошибок. Как пример:
#
#     import os
#
#     pth1 = '/folder_1/data.csv'
#     pth2 = '/folder_2/data.csv'
#
#     if os.path.exists(pth1):
#         query_1 = pd.read_csv(pth1)
#     elif os.path.exists(pth2):
#         query_1 = pd.read_csv(pth2)
#     else:
#         print('Something is wrong')
#
# Ещё на этапе считывания данных можно спарсить дату: за это действие отвечает параметр `parse_dates` метода `read_csv()`, в него нужно передать список с названием полей-дат, и в большинстве случаев дата будет корректно преобразована в нужный формат сразу:)
# Также на этапе считывания данных задать индекс-столбец- за это действие отвечает параметр `index_col`.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Да, верно, info() показывает, что в большом числе столбцов данных нашего датафрейма есть пропуски. Не хорошо, не хорошо ... придётся эти моменты отрабатывать. Пишу "нехорошо" потому, что при кажущейся простоте задачи - обработка пропусков таит в себе массу вопросов как технического плана, так и организационного момента, бизнес-аспекта и даже вопросы этического плана (ниже будет моё эссе на эту тему - где я попытался раскрыть сложность вопроса).
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# По результатам проверки 3,9 тысяч проектов за крайние 2 года (без 2х месяцев) у меня родилось небольшое эссе на тему "удаления vs. спасения" данных, как раз на основе тех ситуаций и вопросов, которые мне коллеги задавали, которые мы обсуждали, уточняли и исправляли ...
#
# <br>
# <br>
# <details>
# <summary style="color: blue; font-size: 18px; font-weight: bold;">▶ <u>Подробнее ...</u></summary>
#
# Желание уменьшить количество пропусков в данных (если такое желание конечно возникает ... но в рабочих проектах, "в жизни" оно как правило возникает) - можно только приветствовать. Приветствовать по 3-м минимум причинам:
#
# 1. это тренировка
#
# 2. это попытка сохранить данные ("данных много не бывает")
#
# 3. самое главное на мой взгляд - развитие аналитического мышления, желания "проникать" в секреты, которые скрывают данные. Когда вначале рождается гипотеза, потом эта гипотеза проверяется на данных (может ли такое быть? подтверждается?) и в финале уже гипотеза облекается в код.
#
# Однако заполнение пропусков в данных не такая простая задача, как кажется ... простого ответа на вопросы: заполнять? удалить? чем заполнять? подходящего под все сценарии, нет ни в одной умной книжке ...
#
# Самый идеальный случай - когда у тебя под рукой есть эксперт в предметной области. Если такой есть - советуйся с ним. Как правило это человек из бизнеса, который знает суть бизнес-процесса и вот именно он даст тебе точный и аргументированный совет - что в данной, конкретной задаче делать с "битыми" полями в строках датафрейма. Ты скажешь ему какой процент пропусков в данных, а он тебе ответит что делать: можно/нельзя удалить и/или даст рекомендации по заполнению. Вообще, как правило такой человек "на любой работе" есть. Для примера, финансовый директор думаю всегда даст рекомендации по финансовым данным, прочие профильные спецы - по своей сфере компетенций. Наверное только в зарождающемся стартапе может не быть каких-то компетенций, но тут уже можно и через фриланс (и т.п.) попробовать найти спеца и просить совета.
#
# Теперь, что делать, если такого человека нет. Я бы ответил так: **ПОПЫТАТЬСЯ** вникнуть в бизнес-проблему самому. Наверное это сложно, если предметная область ну совсем незнакома. Но в общем случае, если бизнес совсем незнаком, то заполнение пропусков в данных наверное, не получиться. В таком случае попробуй ориентироваться на такое правило: если записи с пропусками в ключевых для твоего анализа столбцах составляют 1-3-5-ну может до 10% строк, то попробуй эти записи из оригинального датафрейма вырезать (но сохрани бы в некий df, к которому ты при необходимости можешь всегда обратиться).
#
# В жизни, МНЕ КАЖЕТСЯ, как правило по всему датафрейму заполнять медианой/средним - ну вообще не вариант. Почему? Я бы ответил так - потому, что реальные датафреймы имеют миллионы строк и горизонт в несколько (десятков) лет, и если в 90-2000-е года всё было как-то более -менее стабильно/прогнозируемо, то в нынешней реальности события раскручиваются гораздо быстрее и не прогнозируемо. Пример: ты аналитик в автобизнесе. У тебя есть данные с пропусками в цене для машин в 2005-2007 года. Можно заполнить их средними основываясь на данных 2020-2021?
#
# Может быть и такой вариант, что без заполнения некоторых столбцов некоторые записи по сути **НЕ** имеют смысла, но если их (записи с пропусками удалить), то и данных-то не останется. Ну тогда я бы такой совет дал - всё же заполнять медианой (она к скачкам выбросов более устойчива), но не по всему глобальному датафрейму, а выбрать простые группы (например, группы по интервалу лет - чтобы сгладить турбулентность нынешних лет) или выбрать более сложные группы (например, группы по интервалу лет и одновременно марке автопроизводителя (это я про вымышленный пример с автобизнесом)).
#
# Теперь предположим, что мы выбрали какую-то стратегию заполнения "пропусков", не суть какую (оставить NaN или заполнить "заглушкой"). И в том и в другом случае придётся помнить этот выбор. Ты спросишь почему? Отвечу - потому, что инструменты, применяемые тобой в Питон/Пандас в каких-то случаях могут спокойно пропускать твой выбор, а в каких-то случаях тебе придется этот твой выбор обрабатывать.
#
# Пример 1: мы заполнили пропуски "заглушкой". В этом случае: 1. расчет корреляций значение "заглушку" будет "ловить" (надо отфильтровать!), 2. расчет гипотез также будет "сбивать" правильный вывод (надо отфильтровать!) 3. графики, которые ты будешь строить - будут "заглушку" отображать на осях (нужно фильтровать), 4. в группировках также по-видимому "заглушку" надо будет убирать.
#
# Пример 2: мы оставили пропуски как NaN. В этом случае: 1. метод .corr NaN'ы пропускает (отфильтровать не надо), 2. в расчет гипотез всё равно пропуски отфильтровать 3. графики, которые ты будешь строить могут отображать, а могут не отображать, 4. в группировках NaN'ы по sum() видны не будут, а по count() будут.
#
# Ну и напоследок совсем уже жёсткий пример: додумывать "от себя", бездумно проставлять в пропуски медианные/средние значения - это НЕ верно. Давай же опять "про жизнь". Я писал выше, что в медицине работаю, да? **Предположим** мне принесли данные из онкологического диспансера. Задача: построить модель, которая по некоторым маркерным анализам будет прогнозировать наличие онкологии. **По-простому, ответить, что стоит за строчкой в данных: жизнь или смерть.** Уууууух … аж мороз по коже продирает, правда?
#
# Итак, 1.000.000 записей и 70 столбцов. Данные за 25 лет. 70 столбцов - это поля, с результатами конкретных и очень специфичных анализов. В "начале" данных, 15-20 лет назад, есть пропуски (много), но и в принципе, в данных есть пропуски. Как думаешь - имею я моральное право перед людьми, которые фактически доверяют мне в виде данных свою жизнь огульно подойти к заполнению пропусков?
#
# </details>
# <br>
# <br>
# </div>

# %% [markdown]
# В данном датасете содержится 16715 записей. Для целого ряда столбцов, есть пропущенные значения и некорректные типы данных. Также, необходимо будет проверить данные на наличие явных и неявных дубликатов.

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Спасибо за точный и конкретный вывод по предварительному анализу загруженных данных. Зачастую коллеги ограничиваются исключительно кодом, без слов. Ввиду чего непонятно к каким выводам они пришли и что собираются делать дальше.</div>

# %% [markdown]
# ### Шаг 2. Предобработка данных.

# %% [markdown]
# Явные дубликаты в дубликаты в датасете отсутствуют, но необходимо проверить датафрейм и на наличие неявных дубликатов.

# %%
games.duplicated().sum()

# %% [markdown]
# Проверим датасет на наличие неявных дубликатов, рассмотрим пару "Имя - Игровая консоль".

# %%
duplicates_1 = games[games.duplicated(subset=['name', 'platform'], keep=False)]
display(duplicates_1)

# %% [markdown]
# Данные неявные дубликаты могли возникунуть по множетву причин, которые нельзя предусмотреть
# Напимер, вследствие изменении релизных версий игры.

# %%
old_data = games.shape[0]
games = games.drop_duplicates(subset=['name', 'platform'], keep=False)
print('Текущий размер датафрема:', games.shape)

# %% [markdown]
# В данном случае, рассмотрев датафрейм принемаем решение о том, чтобы удалить все неявные дубликаты, так как количество данных, которое мы отбросили не превысит 10% (всего 10 значений), что является удовлетворительным. Вырезанные значения сохраним в duplicates, к которому при необходимости сможем обратиться.

# %%
# Аналогичный вариант
#games.drop([659, 1591, 4127, 5972, 11715, 14244, 16230], inplace=True)
#games.reset_index(inplace=True, drop=True)
# print('Текущий размер датафрема:', games.shape)

# %% [markdown]
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# **df.duplicated().sum() == 0** не означает, что в данных нет дубликатов (записей).
#
# В реальных рабочих датасетах скорее всего не будет полных дубликатов, но вот неявные наверняка будут встречаться, соответственно с ними надо будет уметь работать. Попробуй найти неявные дубликаты (нужно использовать параметр **subset**). Ну а в нашем учебном проекте пробуй найти дубликаты для пары "Имя - Игровая консоль".
#
# Как их планируешь и планируешь ли обрабатывать?</div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Привет, Александр!
# <br>В данном случае я решил вырезать эти значения из датафрейма (объяснение выше). (Однако, аналогичный вариант есть в ячейке выше, но закомментирован. Если рассмотреть duplicates, то можно предположить, что реальных значения там только три. Остальные можно удалить по индексу.)
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Матвей привет!
#
# Суть этого коммента с 1ой итерации в том, что часто смотрят только на явные дубли (которых очень часто нет), но пропускают анализ дублей по комбинации столбцов.
# </div>

# %% [markdown]
# **Рассмотрим пропуски в датасете**

# %%
games.isna().sum()

# %% [markdown]
# Можно предположить, что пропуски в данных могли возникнуть на этапах копирования, считывания, смене формата при выгрузке данных. Изначально, некоторые поля могли быть заполнены таким образом, что на одном из описанных выше этапов система восприняла их как пропуски. Также не стоит исключать человеческий фактор. Сбор данных мог проводиться из не согласованных источников.
#
# Более подробные описания причин возниконовения пропусков и предложенные решения дадим при рассмотрении отдельных столбцов с аналитикой и выводами по каждому отдельно.

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Добавил предварительные рассуждения о возможной природе возниконовения пропусков в данных выше. Более подробные описания  описаны при рассмотрении отдельных столбцов с аналитикой и выводами по каждому отдельно.
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# **Прежде чем производить какие-либо модификации данных (удалять дубликаты / удалять пропуски / заполнять пропуски «заглушкой / оставлять пропуски «как есть») хотелось бы порассуждать на тему природы пропусков в наших данных**.
#
# Одна из задач этого проекта (согласно брифа):
#
# 1. Объясните, почему заполнили пропуски определённым образом или почему не стали это делать,
#
# 2. Опишите причины, которые могли привести к пропускам
#
# 3. Обратите внимание на аббревиатуру 'tbd' в столбце с оценкой пользователей. Отдельно разберите это значение и опишите, как его обработать.
#
# 4. Также, скажи пожалуйста, какова на твой взгляд причина того, что в столбце с оценками экспертов, с оценками пользователей и с рейтингами так много пропусков? Как ты считаешь, может ли быть какая-то связь с тем, что в столбце с рейтингами >40% пропусков и тем кто эти рейтинги выставляет?</div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Пояснения насчет первых трех пунков в меня присутствуют, просто рассспределены по работе и поясняют причины заполнения пропусков и причины, которые могли к ним привести. Думаю, ты увидел это ниже в работе. Предварительные рассуждения о возможной природе возниконовения пропусков в данных добавил выше.
#
# <br> В итоговом реью ты конкретезировал условие правки, оставив только это:
# <br>
#     Нужен твой комментарий, касающийся природы пропусков в столбце с рейтингами, а именно, может ли быть какая-то связь с тем, что в столбце с рейтингами >40% пропусков и тем, что эти оценки (рейтинги) выставляет именно Американское рейтинговое агентство?
#     Ответ будет в markdown при отдельном разборе этих столбцов.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# **Думаю, ты увидел это ниже в работе. Предварительные рассуждения о возможной природе возниконовения пропусков в данных добавил выше.** - смотри, я пример сейчас приведу - из сериала "Склифосовский" (про медиков сериал .... мне в какой-то момент стало стыдно: работаю в медицине, а про врачей "изнутри" ничего не знаю).  Итак, сериал: ... начинается операция ... оперирующие хирурги ПЕРЕД тем как прикоснуться к пациенту в наркозе ОБСУЖДАЮТ что, как и в какой последовательности будут делать с ним. Обсудили. Все(!!!) согласились. И вот только после этого пациенту отрезают ногу.
#
# Надеюсь этот иносказательный пример ясен? )))) Вначале обсуждаем, понимаем данные и лишь потом "режем"/меняем типы/заполняем пропуски, выполняем прочие модификации в датафрейме. В нашем же случае - ты вначале режешь, а я потом, в соответствующих разделах должен искать почему мы решили так поступить с данными. Объяснил?
#
# **В итоговом реью ты конкретезировал условие правки, оставив только это:** - если я правильно понял вопрос, то вот мой ответ: пункты 1-3 важны здесь. А 4ый важен и здесь и в анализе рейтингов (в саом конце "тетрадки"). Поэтому первые 3 я "оставил" здесь, а вот 4ый ещё раз упомянул сильно ниже.
# </div>

# %% [markdown]
# **Рассмотрим пропуски в столбце year_of_release.**

# %%
games.query('year_of_release.isna()')

# %% [markdown]
# Удалим данные строки, так как в них отсутствует дата выхода, без которой идентифицировать игру крайне проблематично.
# Точную причину возникновения пропусков в данном случае установить невозможно. Количество данных, которое мы отбросили не превысит 10% (всего 10 значений), что является удовлетворительным.

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Небольшой, но жизненный совет: **перед** и **сразу после** удаления строк (и для столбцов тоже будет верно) примени метод .shape к датафрейму. В этом случае наглядно будет видно сколько строк/столбцов было удалено. В некоторых ситуациях может быть ошибка в коде из-за которой удаляется больше чем ожидалось. Но этот способ поможет тебе такую проблему сразу обнаружить.
#
# (Немного рассуждений): да, всего 2 записи (из 16 тысяч) с пропусками в жанрах и названиях (плюс в этих же записях нет ни оценок пользователей, ни оценок критиков, ни рейтингов) и 269 записей (менее 2% из 16+ тысяч) с пропусками в годах выпуска. Казалось бы, надо удалять даже не раздумывая … но единого сценария нет на самом деле. С одной стороны - да, говорят, что "данных много не бывает", удалять записи из-за пропусков, когда датасет измеряется всего лишь сотнями-тысячами записей ой как не хочется.
#
# С другой стороны, если запись не спасти, если в ней несколько полей не заполнено или не заполнены ключевые поля, и ты чувствуешь, что заполнение их медианами/средними приведёт к смещению статистик - надо удалять. Да, можно поставить "заглушку", но тогда надо отдавать отчёт, что во всем последующем коде про эту "заглушку" помнить придётся. Т.е. перед построением всех графиков, гистограмм заглушку надо будет удалить. Перед расчетом корреляций - заглушку надо будет удалить. Перед проверкой гипотез заглушку надо будет удалить.
#
# Я бы так определил способ решения такой задачи: если записи с пропусками в ключевых для моего анализа полях составляют 1-3-5-до 10% строк, то я бы их из оригинального датафрейма вырезал (но сохранил бы в некий df, к которому при необходимости мог бы обратиться).
#
# А вообще, в таких случаях, когда нужно решить - заполнять пропуски или удалять строки с ними из df - всегда ищи эксперта в предметной области и советуйся с ним. Как правило это человек из бизнеса, который значит суть бизнес-процесса и вот именно он даст тебе точный и аргументированный совет - что в данной, конкретной задаче делать с "битыми" полями в строках датафрейма.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Спасибо за совет, учту.
# <br>Момент с удалением до 10% и использую для обоснования удаления полей.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# **Момент с удалением до 10% и использую для обоснования удаления полей.** - Матвей, "удалять до 10%" всё-таки нельзя ))) Нет такого мнемонического правила. Да и я пишу о том, что безвозвратно я не удаляю записи (но сохраняю их в отдельный df и всегда могу к нему вернуться).
# </div>

# %%
#old_data = games.shape[0]
games.query('year_of_release.isna()')
games.dropna(subset=['year_of_release'], inplace=True)
games.reset_index(inplace=True,drop=True)
display(games.isna().sum())
#games.shape[0] / old_data

# %% [markdown]
# **Рассмотрим пропуски в столбце critic_score.**

# %%
games.query('critic_score.isna()')

# %% [markdown]
# В данном случае причины возникновения пропусков в данном столбце могут быть крайне разнообразны так как в мировой игровой индустрии нет четкого контекста выставления critic_score. Платформ и вариантов этой оценки может быть множество, они могут противоречить друг-другу. Далеко не все игры получают именно ту оценку, которая отражена в нашем датасете. Часть игр может не оцениваться вообще.
#
# В данном случае такое большое количество пропусков можно объяснить тем, что critic_score преимущественно выставляет Американское рейтинговое агентство и данная практика наиболее распространена именно там. Поэтому игры, выпущенные в других странах, могут не оцениваться.

# %% [markdown]
# Значения в столбце critic_score нельзя заполнить оценивать по типичным значениям выборки и применять замену, так как она каждый раз уникальна и ставится на основании субъективной оценки (нельзя заполнить средним или медианой). Поэтому заменим Nan на -1, чтобы в дальнейшем привести к необходимому типу данных.

# %%
games.critic_score = games.critic_score.fillna('-1')
games.isna().sum()

# %% [markdown]
# **Рассмотрим пропуски в столбце user_score.**

# %%
games.query('user_score.isna()')

# %% [markdown]
# В данном случае причины возникновения пропусков  в данном столбце могут быть крайне разнообразны так как в игровой индустрии пользовательские оценки выставляются на множестве разных ресурсов и вариантов этой оценки может быть множество, они могут противоречить друг-другу. Далеко не все игры получают именно ту оценку, которая отражена в нашем датасете. Часть игр может не оцениваться вообще, т.к выходила задолго до введения этой практики или наоборот слишком новые и еще не получили оценки.
#
# Также, стоит отметить, что практика выставления оценок наиболее распространена в Северной Америке и вообще крайне субъективная оценка, которая может координально отличаться в зависимости от региона.

# %% [markdown]
# **Обратим внимание на аббревиатуру tbd в столбце user_score.**
#
# Сокращение tbd в данном случае означает, что на данный момент пользовательская оценка окончательно не сформирована и будет определена позже, поэтому все tbd приравняем к Nan.

# %%
games['user_score'] = games['user_score'].replace('tbd', np.NaN)

# %% [markdown]
# Значения в столбце user_score нельзя заполнить оценивать по типичным значениям выборки и применять замену, так как она каждый раз уникальна и ставится на основании субъективной оценки (нельзя заполнить средним или медианой), поэтому заменим Nan на -1, чтобы в дальнейшем привести к необходимому типу данных.

# %%
games.user_score = games.user_score.fillna('-1')
games.isna().sum()

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Один из ключевых моментов этого проекта: ты пропуски в 2 столбцах с оценками ('critic_score' и 'user_score') заполняешь «заглушкой». Это ОК здесь. Но дальше, когда мы будем строить корреляции, а также возможно оценивать платформы в зависимости от оценок (пользователей / экспертов) - надо будет вспомнить этот момент ... Если не вспомнишь и не обработаешь, то дальше скорее всего будет ошибка в результатах анализа, в графиках и в твоих выводах.
#
# Отметь этот момент - возможно нам либо придется вернуться сюда, либо верно отфильтровывать «заглушки» в разделах проверки гипотез и расчета коэффициентов корреляции Пирсона.</div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Я осознано в столбцах с оценками ('critic_score' и 'user_score') пропуски заполнял «заглушкой». Ниже ты сам это пометил зеленым комментарием.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# **Ниже ты сам это пометил зеленым комментарием.** - когда ты их отфильтровал в разделе с расчетом корреляций? Да, ты верно всё сделал. Здесь этот коммент желтый затем, чтобы ниже коллеги не забывали отфильтровать заглушки. Ты не забыл, молодец!
# </div>

# %% [markdown]
# **Рассмотрим пропуски в столбце rating.**

# %% [markdown]
# В данной ситуации пропуски в столбце rating нельзя оценивать по типичным значениям выборки и применять замену так как не все игры обязаны получать рейтинг от ESRB. Некоторые независимые разработчики или игры, выпущенные в других странах, могут не иметь рейтинга ESRB, так как ESRB это Американское рейтинговое агенство и ее оценки действительно значимы только для игр из США и Канады.
#
# К тому же ESRB была основана в 1994 году и игры выпущенные до этого года могут также не иметь ESRB рейтинга. Поэтому присвоим всем пропускам значение 'unknown'.

# %%
games.rating = games.rating.fillna('unknown')
games.isna().sum()

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Отлично, принято правильное решение! «Заглушка» для NaN значений в столбце ‘rating’ – это верное решение в этом проекте. Далее, когда ты будешь анализировать особенности регионов в зависимости от рейтинга ESRB, то увидишь, что если бы они остались NaN, то на графиках их не было бы видно, также такие игры "выпали" бы из анализа и выводов, а это красная ошибка в этом проекте.</div>

# %% [markdown]
# **Преобразуем данные в следующих столбцах в нужные типы.**

# %%
games['year_of_release'] = games['year_of_release'].astype('int')
games['user_score'] = games['user_score'].astype('float')
games['critic_score'] = games['critic_score'].astype('int')
games.info()
games.head(5)

# %% [markdown]
# **Посчитайтем суммарные продажи во всех регионах и запишем их в отдельный столбец.**

# %%
games['total_sales'] = games['na_sales'] + games['eu_sales'] + games['jp_sales'] + games['other_sales']
games.head(5)

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Ещё такой вариант суммирования есть (просто как альтернатива … **псевдокод**): **data[['na_sales','eu_sales','jp_sales', 'other_sales']].sum(axis='columns')** и "присвоить" этот результат новому столбцу в **data**.</div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Спасибо за совет, учту в будущем.
# </div>

# %% [markdown]
# **Часть значений имеет нулевую прибыль, данные значения удалим из датафрейма.**

# %%
games.query('total_sales==0')

# %%
games.drop([16398, 16431], inplace=True)
games.reset_index(inplace=True,drop=True)

# %%
games.info()

# %%
games.shape[0] / old_data

# %% [markdown]
# После проведения предобработки, количество строк в датафрейме уменьшилось с 16715 до 16435 записи. Были удалены пропущенные значения, изменены типы данных. Количество данных, которое мы отбросили составляет не более 10%, что является удовлетворительным. Были посчитаны суммарные продажи во всех регионах и записаны в отдельный столбец.

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Данные загружены, отлично.
#
# Хорошо, что применяешь метод .head()/.sample() таким образом в память не будет загружен весь датасет, объем которого может быть огромным.
#
# Методы .info, .describe, .value_counts(), .unique() как правило часто встречаются и обязательны к применению в задачах по исследованию данных, ведь с их помощью можно получить первые инсайты.
#
# Итак, мы провели предварительный анализ данных, проверили данные на наличие пропусков и затем обработали их (аргументированно заполнили / удалили / оставили как есть). Теперь можно приступать собственно к анализу данных и ответам на вопросы проекта.</div>

# %% [markdown]
# ### Шаг 3. Исследовательский анализ данных.

# %% [markdown]
# Дадим описание и визуализируем общую информацию об игровой индустрии в рассматриваемый период.

# %% [markdown]
# **Построим сводную таблицу, отображающую количество релизов игр в зависимости от года, отсортируем в проядке убывания и выведем значения на экран. По полученным значениям построим диаграмму.**

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Агрегация по count() покажет нам число игр, выпущенных на всех платформах, в разрезе лет. Т.е. если одна и та же игра (name) вышла в некоем году на одной платформе, агрегат == 1. Если на 2-х платформах, агрегат == 2, ну и так далее. У меня вопрос к тебе – что в твоем случае, в написанном тобой коде мы считаем выпуском игры (в этом, некоем году)?
#
# Возможно, чтобы получить истинное количество «игр по годам» нам следует поискать дубликаты (используя subset по (Годам - Названиям игр) и затем исключить из полного датафрейма все дубли за исключением одной, «первой», строки? Как ты считаешь?</div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Релиз (выпуск) одной и той же игры может быть на разных платформа в разные года. Поэтому я решил оставить оба варианта диагрммы, ниже добавл вариант с истинным количество «игр по годам». Удалил дубликаты из пары (Год - Название игры) за исключением одной, «первой», строки. Код будет ниже старго.
# <br> Ты не пометил это как критическую ошибку, поэтому пусть будут оба варианта, тот, который ты мне предлагаешь рассмотреть будет сделан на копии games и не будет менять его, так как он нужен в дальнейших пунктах.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# В этом вопросе не было подвоха. И верными могут быть оба варианта – в зависимости от угла зрения на эту задачу. Этот жёлтый комментарий не про то, чтобы что-то сразу делать с данными, а "про подумать", как и почему мы будем работать с играми, которые в **определенном году** выходят сразу на нескольких платформах. Будем мы их считать разными, уникальными играми. Или мы их будем считать, как одну игру, которая вышла в этом текущем году? Так что, то, что вопрос обдуман, объяснен и реализовано свое видение - молодец!
# </div>

# %% [markdown]
# Построим сводную таблицу, отображающую количество релизов игр в зависимости от года, отсортируем в проядке убывания и выведем значения на экран. По полученным значениям построим диаграмму.

# %%
games_frequency = games.pivot_table(index = 'year_of_release', values = 'name', aggfunc = 'count')\
                       .sort_values(by = 'name', ascending = False)

games_frequency.columns = ['Количество игр']
games_frequency.rename_axis('Год выпуска', inplace=True)
display(games_frequency)
display(games_frequency.describe())

plt.figure(figsize=(12, 6))
sns.set_theme(style="darkgrid")  
ax = sns.barplot(y=games_frequency['Количество игр'], x=games_frequency.index, palette='viridis')
ax.set_title('Количество релизов игр в зависимости от года')
plt.xticks(rotation=90) 
plt.show()

# %% [markdown]
# На основании построенной таблицы и диаграммы можем сделать выбор о том, что в рассматриваемый период в 36 лет (1980-2016) количество релизов игр начало резко расти с 1994 года и достигло пика в 2009 году. Это наиболее важный период в данном датасете.
# Разброс данных значителен std = 451. В среднем, в рассматриваемы период выпускалось 338 игр (Q2).
#
# Можно отметить некую периодичность в падении количества релизов (1999-2000, 2003-2004, 2009-2013). Это можно связать с выходами новых платформ, ростом системных требований, спецификой игровой индустрии и.т.д. Начиная с 2012 наблюдается стабилизация объема релизов.

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
#  Ниже вариант с истинным количество «игр по годам». Удалил дубликаты из пары (Год - Название игры) за исключением одной, «первой», строки. На новых данных вывод практически не изменился.
# </div>

# %%
games_copy = games.copy()
df_1_copy = games_copy[games_copy.duplicated(subset=['name', 'year_of_release'], keep=False)]
df_1_copy.shape

# %%
games_copy = games_copy.drop_duplicates(subset=['name', 'year_of_release'], keep=False)
games_copy.shape

# %%
games_frequency = games_copy.pivot_table(index='year_of_release', values='name', aggfunc='count')\
                            .sort_values(by='name', ascending=False)
games_frequency.columns = ['Количество игр']
games_frequency.rename_axis('Год выпуска', inplace=True)


display(games_frequency.head())
display(games_frequency.describe())
plt.figure(figsize=(12, 6))
sns.set_theme(style="darkgrid")
ax = sns.barplot(y=games_frequency['Количество игр'], x=games_frequency.index, palette='viridis')
ax.set_title('Количество релизов игр в зависимости от года')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# На основании построенной таблицы и диаграммы можем сделать выбор о том, что в рассматриваемый период в 36 лет (1980-2016) количество релизов игр начало резко расти с 1994 года и достигло пика в 2008 году. Это наиболее важный период в данном датасете.
# Разброс данных значителен std = 252. В среднем, в рассматриваемы период выпускалось 229 игр (Q2).
#
# Можно отметить некую периодичность в падении количества релизов (1999-2000, 2003-2004, 2009-2013). Это можно связать с выходами новых платформ, ростом системных требований, спецификой игровой индустрии и.т.д. Начиная с 2012 наблюдается стабилизация объема релизов.

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Просто супер: график подписан, оси подписаны. Не часто на самом деле такой скрупулёзный подход к оформлению встречается. Молодец! Также, здорово, что (ниже) есть объяснение поведения графиков. Пытаться понять полученный результат - важная часть работы аналитика.
#
# Я закончил физико-математический факультет Петрозаводского государственного университета. Нас там с первого курса приучили - если на сдачу лабораторной работы по физике приходишь с графиком, на котором не подписано общее название, названия осей (с единицами измерений), единичная шкала - всё сдача заканчивается не начавшись. Или если у моей лабораторной работы отсутствует вывод: что делали? по какой методике? что "намеряли"? как интерпретировали? какой финальный вывод? - всё, тоже на выход. Ну и в принципе сейчас, на текущей работе: код, который написан в тетрадке мало кому понятен и не сильно кому интересен. Важнее детальные выводы и тренды, которые попадут на слайд презентации в PowerPoint. Именно поэтому столь важное значение в аналитике данных придается промежуточным выводам и уж тем более финальному.
#
# </div>

# %% [markdown]
# **Построим сводную таблицу, отображающую суммарное количество продаж игр в зависимости от платформы. По полученным значениям построим диаграмму.**

# %%
platform_frequency = games.pivot_table(index = 'platform', values = 'total_sales', aggfunc = 'sum')\
                          .sort_values(by = 'total_sales', ascending = False)
platform_frequency.columns = ['Суммарные продажи']
platform_frequency.rename_axis('Платформа выпуска', inplace=True)
display(platform_frequency)
display(platform_frequency.describe())

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Обрати внимание на ячейку, которую я сейчас комментирую – видишь слайдер («бегунок») снизу? Он показывает, что код не помещается в видимые границы ячейки (и чтобы его полностью «прочитать» - нужно использовать мышь. Код очень длинный.
#
# Код очень длинный (а PEP8 определяет длину строки в 79 символов) - попробуй длинные - переносить, а между строками использовать пустые строки. Ну и желательно код комментировать, хотя бы коротко (что делаешь и каков будет результат - так твоим коллегам будет проще за твоей мыслью следить). Этот комментарий может относиться к нескольким ячейкам этой «тетрадки».
#
# Хороший разработчик форматирует и комментирует свой код, тогда другие разработчики быстрее разберутся в программе. Это важно, ведь код чаще читают, чем пишут: напишет один, а прочтут — сотни или тысячи (если код хороший).
# «Пишите код так, как будто сопровождать его будет склонный к насилию психопат, который знает, где вы живете.» ©1991, John F. Woods, разработчик
#
# ---
# Давай обсудим стиль кодирования (программирования)? Смотри что сейчас происходит в этой ячейке (**не всё применимо к твоему коду здесь, но я попытался собрать и представить здесь самые ценные советы из PEP8 по организации кода**) и что можно сделать по-другому, чуть лучше:
#
# 1. Комментарии к строке кода: они должны располагаться выше соответствующей строки кода (выше строки к которой относятся) и должны быть от этой строки отделены пустой строкой. Если же они расположены справа, то для того чтобы увидеть, что там написано приходится пользоваться скроллиногом. Надо добиться того, чтобы ячейку не приходилось прокручивать, т.к. это не добавляет удобства ни при отладке кода, ни для понимания что в этой ячейке "происходит". Как альтернатива – комментарий может размещаться выше, в Markdown-ячейке.
#
# 2. Бывает, что встречаются очень длинные строки кода, которые также уходят за правый край ячейки. Такие строки должны разбиваться разделителем (вот таким: \\). Это best practice, требование PEP8, а именно: PEP8 определяет длину строки в 79 символов.
#
# 3. **В идеале**: одна ячейка - одна строка кода. Почему так? Да как минимум из соображения понятности: будучи выполненной, под этой ячейкой должен отображаться результат трансформации данных. Ты или твой коллега должны видеть, как поменялись данные после выполнения ячейки с кодом. Следующая ячейка - ещё строка кода и соответствующим output'ом. Будешь делать так - коллеги будут тебе благодарны за то, что легко будут следовать за твоей мыслью. И отладку это упрощает. Ну и как противоположность - можно в одну ячейку "положить" результат 3-х последовательных groupby + ещё чего-нибудь. Разобраться с ходу "что происходит" будет очень трудно, придётся всё равно код разносить по ячейкам и смотреть последовательно что происходит. Но ведь логично это делать удобным способом сразу, ведь так?
#
# 4. Неиспользуемые, закомментированные строки выше вынеси в другую ячейку, отдельную, выше. Можешь для удобства своего прокомментировать (на память). И оставь там это код, так, чтобы он не смешивался с рабочим кодом.
#
# p.s. возможно и в следующих ячейках твоей «тетрадки» будет код, который просмотреть можно только используя мышку, но я этот момент более комментировать не буду – просто обращай внимание на слайдер под ячейкой с кодом.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Постарался везде сократить строки, чтобы они соответствовали требованиям PEP8 (79 символов). Большая часть пояснений у меня вынесена в markdown. Другая же часть комментариев в большей степени для меня, чтоб при необходимости, спустя время, я мог быстро вспонить что делал.
# </div>

# %%
plt.figure(figsize=(12, 6))
sns.set_theme(style="darkgrid")  
ax = sns.barplot(y=platform_frequency['Суммарные продажи'], x=platform_frequency.index, palette='viridis')
ax.set_title('Количество релизов игр в зависимости от платформы выпуска')
plt.xticks(rotation=90) 
plt.show()

# %% [markdown]
# Так как конкретное количество платформ для анализа выбирается произвольно, то выберем 5 платформ с наибольшими суммарными продажами.

# %% [markdown]
# **Построим распределение платформ по годам. Определим за какой характерный срок появляются новые и исчезают старые платформы.**

# %% [markdown]
# Создадим сводную таблицу с суммарными продажами по годам для каждой платформы

# %%
platform_sales_pivot = games.pivot_table(index=['platform', 'year_of_release'], values='total_sales', aggfunc='sum')

# %% [markdown]
# Выберем только топ-5 платформ

# %%
top_platforms = platform_frequency.head(5)
top_platforms

# %%
# В цикле для каждой из 5 платформ построим график срока существования. 
plt.figure(figsize=(12, 6))
for name in top_platforms.index:
    platform_data = platform_sales_pivot.loc[name].reset_index()
    plt.plot(platform_data['year_of_release'], platform_data['total_sales'], marker='o', label=name)

# Создадим список со сроками существования каждой платформы
average_lifespan = {}
for name in top_platforms.index:
    platform_years = games.query('platform == @name')['year_of_release']
    lifespan = platform_years.max() - platform_years.min()
    average_lifespan[name] = lifespan

# Создадим DataFrame из словаря со сроками существования каждой платформы
lifespan_df = pd.DataFrame(list(average_lifespan.items()), columns=['Платформа', 'Сроки существования'])

plt.title('Зависимость суммарных продаж от года выпуска для лидеров рынка')
plt.xlabel('Год выпуска')
plt.ylabel('Суммарные продажи (млн)')
plt.legend()
plt.show()
lifespan_df

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Совсем немногие коллеги делают выборку топ-Х платформ так как это делаешь ты, в коде. Процентов 80 формируют подобный list вручную. Молодец!</div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# А что за артефакт у платформы DS в 1985 году? В каком году DS "свет увидела"?
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Понял, что нужно убрать. Решил оставить оба графика для большей наглядности. Отразил все этапы избавления от данного значения. Ниже избавился от данного аномального занчения. Вывод подправил.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# **Ниже избавился от данного аномального занчения.** - Да, верно что убираешь. Это пример учебного бага в наших учебных данных. "В жизни" много "такого" будет ....
# </div>

# %% [markdown]
# Заметим, что платформа DS впервые вышла 21 ноября 2004 года. Для оценки данного отклонения рассмотрм значения в нашем датафрейме, которые были ранее.

# %%
platform_sales_pivot.query('platform == "DS" and year_of_release < 1990')

# %%
platform_sales_pivot.drop(
    platform_sales_pivot[
        (platform_sales_pivot.index.get_level_values('platform') == "DS") & 
        (platform_sales_pivot.index.get_level_values('year_of_release') < 2004)].index, inplace=True)

# %% [markdown]
# В данных только одна строка и это явная ошибка возникшая при заполнении данных в столбце name. Принимаем решение удалить эту строку по её индексу.

# %%
platform_sales_pivot.query('platform == "DS" and year_of_release < 2004')

# %% [markdown]
# Перестроим график срока существования платформ по обновленным данным.

# %%
plt.figure(figsize=(12, 6))
for name in top_platforms.index:
    platform_data = platform_sales_pivot.loc[name].reset_index()
    plt.plot(platform_data['year_of_release'], platform_data['total_sales'], marker='o', label=name)
    
plt.title('Зависимость суммарных продаж от года выпуска для лидеров рынка')
plt.xlabel('Год выпуска')
plt.ylabel('Суммарные продажи (млн)')
plt.legend()
plt.show()

# %% [markdown]
# На основании построенной таблицы и графика можем сделать выбор о том, что в среднем сроки существования платформ составляют 10-11 лет. Половину этого срока популярность палтформы возростает, достигая пика, затем спустя прмерно 5 лет послее ее появления на рынке количество продаж начинает падать. Лидерами продаж за весь период являются PS2 и X360.

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Подтверждаю «около 10 лет», как корректный интервал, описывающий средний срок жизни игровой платформы.
# </div>

# %% [markdown]
# **Для дальнейшего анализа лидиров по продажам и потенциально прибыльных платформ необходимо определиться с актуальным периодом.**

# %% [markdown]
# Несмотря на то, что однозначное определение актуального периода сформировать нельзя, выберем оптимальный период в 3 года (2014-2016), так как на игровую индустрию влияет множество факторов и рынок быстро меняется, а нам необходимо определить тренд и сезонность.

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Правильный выбор диапазона!
#
# Это на самом деле один из подводных камней этого проекта!
#
# Коллеги могут выбирать для анализа очень большой интервал данных, но для целей прогнозирования продаж на следующий год даже в традиционных бизнесах редко берут данные более чем за 2-4 года. И в такой динамично меняющейся индустрии, как компьютерные игры также не стоит брать слишком большой временной интервал - иначе обязательно захватишь уже отжившие тренды.
#
# В нашем учебном проекте, я с тобой соглашусь, что 3 года: 2014 - 2015 + неполный 2016 - ОК.
#
# </div>

# %%
# Софрмируем необходимую таблицу, которой будем пользоваться в дальнейшем
actual_period_data = games.query('year_of_release >= 2014').reset_index()
actual_period_data.head()

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Очень хорошо, что результат запроса/’среза’ ты присваиваешь новому датафрейму. Таким образом оригинальный датафрейм ты оставляешь нетронутым, не перезаписываешь (вдруг нам опять понадобятся данные из него чуть ниже). Это верное решение. Best practice. Молодец!</div>

# %% [markdown]
# **Сначала, рассмотрим общее количество релизов игр в зависимости от платформы выпуска с 2014 по 2016.**

# %%
plt.figure(figsize=(12, 6))
actual_platforms = actual_period_data.pivot_table(index='platform', values='total_sales', aggfunc='sum')\
                                     .sort_values(by='total_sales', ascending=False)
# Строим диаграмму для общего количества релизов игр в зависимости от платформы выпуска
ax = sns.barplot(x=actual_platforms.index, y=actual_platforms['total_sales'])

ax.set_title('Общее количество релизов игр в зависимости от платформы выпуска с 2014 по 2016')
plt.xlabel('Платформа выпуска')
plt.ylabel('Суммарные продажи (млн)')
plt.show()
print('Суммарные продажи в зависимости от жанра с 2014 по 2016')
display(actual_platforms)
print('Статистические данные')
display(actual_platforms.describe())

# %% [markdown]
# **Определим тенденцию продаж в данном промежутке.**

# %% [markdown]
# В данном случае используем пармаетр hue='year_of_release' для разделения данных по году выпуска игр, что позволяет визуально сравнивать суммарные продажи игр для каждой платформы в разные годы выпуска.

# %%
plt.figure(figsize=(12, 6))
annual_dependence = actual_period_data.pivot_table(index=['platform', 'year_of_release'], values='total_sales', aggfunc='sum').reset_index()
# Строим диаграмму для каждого года, использую hue='year_of_release'
ax = sns.barplot(data=annual_dependence, x='platform', y='total_sales', hue='year_of_release')

ax.set_title('Количество релизов игр с 2014 по 2016')
plt.xlabel('Платформа выпуска')
plt.ylabel('Суммарные продажи (млн)')
plt.show()

# %% [markdown]
# На основании построенных таблиц и диаграммы можем сделать выбор о том, что к началу 2017 года, лидирующими платформами являются PS4, XOne и 3DS. С 2016 года наблюдается спад продаж по всем платфомам. В среднем для платформы в данном промежутке времени суммарные продажи составляют 45.6 (Q2).

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Здесь всё отлично. Платформы, которые имеют перспективы для продаж в 2017 году ты верно определяешь и отрисовываешь их на графике! Супер!
#
# Ну и твой вывод отражает и описывает найденные тобой закономерности в данных.
# </div>

# %% [markdown]
# **Построим график «ящик с усами» по глобальным продажам игр в разбивке по платформам чтобы визуально оценить разброс и наличие выбросов в данных. Опишем статистические данные по суммарным продажам.**

# %%
plt.figure(figsize=(12,6))
sns.set_theme(style="darkgrid")  
ax1 = sns.boxplot(data=actual_period_data, x='platform', y='total_sales', palette='viridis')
ax1.set_title('Суммарные продажи по платформам с 2014 по 2016')
plt.xlabel('Платформа выпуска')
plt.ylabel('Суммарные продажи (млн)')
plt.ylim(0,5)
plt.show()

plt.figure(figsize=(12,6))
sns.set_theme(style="darkgrid") 
ax2 = sns.boxplot(data=actual_period_data, x='platform', y='total_sales', palette='viridis')
ax2.set_title('Суммарные продажи по платформам с 2014 по 2016 (крупная версия)')
plt.xlabel('Платформа выпуска')
plt.ylabel('Суммарные продажи (млн)')
plt.ylim(0, 0.85)
plt.show()

print('Статистические данные о суммарных продажах по платформам с 2014 по 2016')
display(actual_period_data.groupby('platform')['total_sales'].describe())

# %% [markdown]
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# К сожалению, на этом графике **уверенно визуально** сравнивать квартили (медиану, 25ый и 75ый) у части платформ не получается (у PS4 или у WiiU медиана больше? насколько?). Велика вероятность ошибки. Для более обоснованных выводов на основе **только графика** (иначе зачем такой **неговорящий график нужен**) нужно сделать дополнительный график, где будет отображена только нижняя часть boxplot-ов. Этого можно добиться, например, задав параметр ylim
#
# То есть, я бы предложил после этого графика ещё один построить, в котором бы сами "ящики" были лучше видны. На том, что выше выбросы их фактически "забили". Попробуй использовать в параметре ylim, значение, которое ещё больше ограничит значение по OY "сверху" (например, ylim(0, 0.85).
#
# Или ещё вариант, вместо этого, слишком мелкого, сделай 2 отдельных, на 2-х больших канвасах: на первом графике -  все боксплоты, БЕЗ ylim. В этом случае некоторые "ящики" будут видны плохо, но зато хорошо будут видны как у всех "ящиков" выглядят выбросы.
#
# На втором: все боксплоты, но с ylim == значению (по OY), которое будет является ближайшим к самому большому из 1,5 межквартильных размахов боксплота. В этом случае все "ящики" растянутся почти на весь график, а выбросы будут срезаны.
#
# Ну а в твоем случае, из-за того, что на графике не разобрать квартили - для точного сравнения "ящиков" мы вынуждены будем использовать describe().</div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Решил воспользоваться первым советом и построить доп. график, в котором "ящики" лучше видны. Задал ylim(0, 0.85). Теперь можно делать выводы на основе обоих графиков.
# Вывод подправил.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Да, теперь значительно лучше! Теперь «ящики» платформ можно визуально сравнивать между собой прямо на графике.
# </div>

# %% [markdown]
# На основании диаграмм размаха можем сделать выбор о том, что в рамках выбранного периода существует большой разброс в объемах продаж, значительная разница между Q3 и Q1. Лидерами продаж являются PS4, XOne и 3DS.
#
# Так как присутствует большое количество аномалий, существующую тенденцию лучше определяет медиана (Q2). Наибольшее среднее значение продаж имеют XOne(Q2=0.2 млн), WiiU(Q2=0,19 млн) и PS4 (Q2=0,185 млн). Наимаеньшее среднее количество продаж наблюдается у PSV (Q2=0.04 млн) и PSP (Q2=0.02 млн).

# %% [markdown]
# **Оценим, как в рамках рассматриваемого периода влияют на продажи внутри трех самых популярных платформ (PS4, XOne, 3DS) отзывы пользователей и критиков.**

# %% [markdown]
# Сформируем массив из трех самых популярных платформ (PS4, XOne, 3DS) платформ.

# %%
top_3_platforms  =  actual_platforms.index.unique()[:3]
display(top_3_platforms)

# %% [markdown]
# Для каждой платформы, в цикле, построим диаграммы распределения и вычислим корреляцию между оценкой пользователей и продажами в разрезе отдельных платформ

# %%
# Перебираем каждую платформу и строим диаграммы рассеяния
for platform in top_3_platforms:
    df_platform = actual_period_data.query('platform == @platform and user_score > -1 \
                                           and critic_score > -1')
    
    # Создим subplots для каждой платформы
    fig, (ax1, ax2) = plt.subplots(1, 2,figsize=(12,6))
    
    # Построим диаграммы расспределения оценок пользователей и суммарного объема продаж.
    ax1.scatter(x=df_platform.user_score, y=df_platform.total_sales, alpha=0.5, color='green')
    ax1.set_title(f'Зависимость оценок пользователей и продаж для {platform}')
    ax1.set_xlabel('Оценка пользователей')
    ax1.set_ylabel('Суммарные продажи (млн)')
    
    # Построим диаграммы расспределения оценок критиков и суммарного объема продаж.
    ax2.scatter(x=df_platform.critic_score, y=df_platform.total_sales, alpha=0.5, color='green')
    ax2.set_title(f'Зависимость оценок критиков и продаж для {platform}')
    ax2.set_xlabel('Оценка критиков')
    ax2.set_ylabel('Суммарные продажи (млн)') 

    plt.show()
    # Построим диаграммы расспределения оценок критиков и суммарного объема продаж.
    print('Коэффициент корреляции между оценками пользователей и суммарными продажами по платформе',\
          platform, '=', df_platform['user_score'].corr(df_platform['total_sales']).round(2))
    print('Коэффициент корреляции между оценками критиков и суммарными продажами по платформе',\
          platform, '=', df_platform['critic_score'].corr(df_platform['total_sales']).round(2))

# %% [markdown]
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# ![image.png](attachment:image.png)
#
# Если бы в 'user_score' и 'critic_score' мы оставили бы NaN (не заполняли «заглушкой»), то .corr бы их при расчете корреляций не стал использовать (и мы получили бы коэффициенты для **реальных** оценок). Сейчас же своё влияние на значения коэффициентов корреляции имеют и искусственно сгенерированные нами оценки, за фактическую корректность которых мы ручаться совсем не можем.</div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Добавил необходимое условие фильтрации по critic_score.
# <br> Насколько я понял, заменив Nan на заглушку и правильно отфильтровав значения при срезе, мы избавляемся от проблемы влияния на значения коэффициентов корреляции искусственно сгенерированных нами оценок (т.е -1), и теперь данные для построения графиков корректны.
# <br> (Т.е ошибка была в том, что я забыл отфильтровать значения по critic_score, на который ранее поставил заглушку).
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# **Насколько я понял, заменив Nan на заглушку и правильно отфильтровав значения при срезе, мы избавляемся от проблемы влияния на значения коэффициентов корреляции искусственно сгенерированных нами оценок (т.е -1), и теперь данные для построения графиков корректны.** - да, всё верно. Если -1 у критиков не убирать, то они на 1ой итерации могли влиять на расчет коэффициентов корреляции (так как были не "живыми" оценками, а техническими "заглушками").
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Понимание структуры данных на самом деле дает нам основание использовать метод Спирмена/Кендалла, а не Пирсона (при оценки степени корреляции признаков). Почему так? Присоединяю табличку в помощь (и для последующих повторных обращений к ней).
#
# p.s. почему в этом проекте требуется оценка корреляций методом Пирсона? Скорее всего потому что новой теории нет у вас в Тренажере (но наверняка это будет дальше).
# </div>
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **На основании построенных диаграмм размаха можем сравнить связь между оценками пользователей и критиков с суммарными продажами рассматириваемых платформ (PS4, XOne и 3DS):**
#
#  - Линейная связь между оценками пользователей и суммарными продажами по платформам, практически отсутствует. Значения могут увеличиваться, но не обязательно в точной пропорции.
#     - PS4: Коэффициент корреляции = -0.04 - очень слабая отрицательная корреляция
#     - XOne: Коэффициент корреляции = -0.09 - очень слабая отрицательная корреляция
#     - 3DS: Коэффициент корреляции = 0.28 - слабая положительная корреляция
#
# Таким образом, можем сделать вывод о том, что оценки пользователей корреляции с суммарными продажами не имеют (только у 3DS слабая положительная корреляция).
#
#  - Линейная связь между оценками критиков и суммарными продажами по платформам существует, но слабая. Значения могут увеличиваться, но не обязательно в точной пропорции.
#     - PS4: Коэффициент корреляции = 0.4 - слабая положительная корреляция
#     - XOne: Коэффициент корреляции = 0.42 - слабая положительная корреляция
#     - 3DS: Коэффициент корреляции = 0.28 - слабая положительная корреляция
#
# Таким образом, можем сделать вывод о том, что оценки критиков имеют прямую, средне-слабую корреляцию с суммарными продажами.
#
# Стоит отметить, что для платформы 3DS оценки пользователей критиков имеют одинаковую связь (прямой, слабой степени выраженности).

# %% [markdown]
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# ![image.png](attachment:image.png)
#
# Дьявол кроется в формулировках - говорить так в общем случае неверно.
#
# ---
# Формулировать, что коэффициент  корреляции (Пирсона) между 2 переменными (в нашем случае между total_sales и critic_score / user_score) есть показатель того, что **на количество продаж влияет оценка ** - неверно. Корреляция не подразумевает наличие причинно-следственной связи между переменными.
#
# Коэффициент свидетельствует **о наличии или отсутствии линейной связи** между переменными, и **измеряет выраженность** этой связи. Другими словами, коэффициент корреляции - это инструмент, с помощью которого можно проверить гипотезу о **линейной** зависимости и измерить степень этой зависимости.
#
# Например, в нашем случае, связь между продажами и оценками экспертов для всех платформ является **прямой, слабой** степени выраженности (во всех случаях коэффициент около 0,3-0,4).
#
# Я бы твою фразу переписал бы так (**ПРИМЕР**): "Оценки критиков демонстрируют прямую, средне-слабую корреляцию с "цифрами" продаж. Оценки пользователей корреляции с продажами не имеют".
#
# Понимаешь, нет влияния оценок на продажи. Коэффициент корреляции Пирсона не про это. Он про линейную зависимость 2-х переменных. И ещё, это коэффициент **НЕ ОБЪЯСНЯЕТ** зависимость, он **НЕ ГОВОРИТ** почему наблюдается такой эффект, но просто констатирует факт, что корреляция наблюдается (например, "мы видим, что те игры, которым наши эксперты дают высокие оценки - продаются лучше". А вот почему они продаются лучше - можно только предполагать ... разные причины могут быть). Вот смешная статейка на эту тему: https://ktonanovenkogo.ru/voprosy-i-otvety/korrelyaciya-chto-ehto-takoe-prostymi-slovami.html </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Изменил формулировки, сформулировал по правильным данным. Выводы исправил.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Да, теперь всё верно!!!
#
# ---
# Но ещё раз, в связи с частыми ошибками в формулировках, **на будущее**: объяснять корреляцию/зависимость **причинной связью** нельзя.
#
# Пример: на улице начали появляться мухи и одновременно стали увеличиваться продажи мороженного. Есть такая зависимость? Да, конечно есть!
#
# Но, правда, что мороженного стали есть больше потому, что мухи "полетели"? Причина в мухах? Нет, конечно же нет. Причина в том, что поднимается температура воздуха (третья переменная), начинается лето.
# </div>

# %% [markdown]
# **Рассмотрим общее распределение игр по жанрам в актуальный период. Проверим, выделяются ли жанры с высокими и низкими продажами.**

# %%
plt.figure(figsize=(12, 6))
sns.set_theme(style="darkgrid") 
actual_genres = actual_period_data.pivot_table(index='genre', values='total_sales', aggfunc='sum')\
                                  .sort_values(by='total_sales', ascending=False)
ax = sns.barplot(x=actual_genres.index, y=actual_genres['total_sales'])

ax.set_title('Суммарные продажи в зависимости от жанра с 2014 по 2016')
plt.xlabel('Жанр')
plt.ylabel('Суммарные продажи (млн)')
plt.show()
print('Суммарные продажи в зависимости от жанра с 2014 по 2016')
display(actual_genres)
print('Статистические данные')
display(actual_genres.describe())

# %%
plt.figure(figsize=(12,6))
sns.set_theme(style="darkgrid")  
ax = sns.boxplot(data=actual_period_data, x='genre', y='total_sales', palette='viridis')
ax.set_title('Суммарные продажи по платформам с 2014 по 2016')
plt.xlabel('Платформа выпуска')
plt.ylabel('Суммарные продажи (млн)')
plt.ylim(0,10)
plt.show()
print('Статистические данные по каждому жанру с 2014 по 2016')
display(actual_period_data.groupby('genre')['total_sales'].describe())

# %% [markdown]
# На основании диаграмы суммарных продаж можем сделать выбор о том, что в рамках выбранного периода существует большой разброс в объемах продаж, самым продаваемым жанром является Action (199.36 млн), затем Shooter(170.94 млн) и Sports (109.48). Самые невостребованные жанры это Strategy	(3.96) и Puzzle (2.21).
#
# Так как присутствует большое количество аномалий, существующую тенденцию лучше определяет медиана (Q2). Из диаграммы размаха видно, что наибольшее среднее значение продаж имеют игры жанра Shooter(Q2=0.515 млн), Sports(Q2=0.18 млн).

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Это одно из сложных мест в этом проекте: зачастую коллеги делают вывод о выгодности жанра по количеству проданных копий или по суммовым продажам (по этому параметру должны бы выиграть Action-игры), а не по среднему/медианному значению.
# Отлично что ты понимаешь, что общие продажи - это не очень корректная метрика для поиска наиболее прибыльного жанра. За высокими показателями общих продаж может скрываться множество мелких игр с низкими продажами. Или 2-3 звезды и куча провалов. Лучше найти жанр, где игры стабильно приносят высокий доход - для этого стоит рассмотреть средние (или медианные продажи или продажи, приведенные на одну игру – это хорошо обычно демонстрирует график «ящик с усами» (но можно и просто смотреть на цифры продаж или даже использовать столбиковую(?)/столбцовую(?) диаграмму)), что собственно ты и делаешь!</div>

# %% [markdown]
# ### Шаг 4. Портрет пользователя каждого региона.

# %% [markdown]
# **Определим самые популярные платформы каждого региона  отдельно (NA, EU, JP). Опишем различия в долях продаж.**

# %% [markdown]
# Создим сводную таблицу для суммарных продаж в NA для каждой платформы. Выведем топ-5 платформ, остальные объеденим. Построим круговую диаграмму по полученным данным.

# %%
# Заведем сводную таблицу для суммарных продаж. 
na_platform_pivot_table = pd.pivot_table(actual_period_data, index='platform', values='na_sales', aggfunc='sum')\
                            .sort_values('na_sales', ascending=False)

# Из полученной сводной таблицы вычислим продажи для "остальных" платформ.
na_other_sales = na_platform_pivot_table['na_sales'][-5:].sum()

# Используем метод .copy() для работы с копией na_platform_pivot_table.
na_platform_pivot_table_combined = na_platform_pivot_table[:-5].copy()  
na_platform_pivot_table_combined.loc['Остальные'] = na_other_sales

# Построим круговую диаграмму по полученным данным.
fig, ax = plt.subplots(figsize=(12, 6))
na_platform_pivot_table_combined['na_sales'].plot(kind='pie', labels=na_platform_pivot_table_combined.index,\
                                                  autopct='%1.1f%%', colors=sns.color_palette('viridis'))
ax.set_title('Соотношение продаж по платформам в Северной Америке')
plt.show()

print('Топ-5 платформ по продажам в Северной Америке')

display(na_platform_pivot_table.head())

print('Общее число продаж по платформам в Северной Америке')
        
display(na_platform_pivot_table.sum())

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Специалисты по визуализации утверждают, что наш мозг?/глаз? **очень плохо "различает различия"** между "примерно одинаковыми" кусочками pie-диаграммы. Ну и соответственно рекомендуют использовать столбиковые?/столбцовые? диаграммы. У тебя конечно цифрами "кусочки" подписаны, но тем не менее мнение такое в среде специалистов по визуализации существует.
#
# Я ни в коем случае не против pie-диаграмм! Я просто призываю помнить об их обманчивой сущности )))
#
# p.s. по факту приёма проекта я пришлю тебе набор книг в котором среди прочих будут и книги по визуализации.</div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Спасибо за совет, учту в будущих проектах. Тут дело в том, что задание было сформулировано так: "Опишите различия в долях продаж", что на прошлых проектах всегда означало, что визуализироваь нужно именно pie-диаграммой.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Да Матвей, ты прав!
#
# Но подсветить этот момент хотелось ... выбрал желтый цвет.
# </div>

# %% [markdown]
# Создим сводную таблицу для суммарных продаж в EU для каждой платформы. Выведем топ-5 платформ, остальные объеденим. Построим круговую диаграмму по полученным данным.

# %%
# Заведем сводную таблицу для суммарных продаж. 
eu_platform_pivot_table = pd.pivot_table(actual_period_data, index='platform', values='eu_sales', aggfunc='sum')\
                            .sort_values('eu_sales', ascending=False)

# Из полученной сводной таблицы вычислим продажи для "остальных" платформ.
eu_other_sales = eu_platform_pivot_table['eu_sales'][-5:].sum()

# Используем метод .copy() для работы с копией eu_platform_pivot_table.
eu_platform_pivot_table_combined = eu_platform_pivot_table[:-5].copy()  
eu_platform_pivot_table_combined.loc['Остальные'] = eu_other_sales

# Построим круговую диаграмму по полученным данным.
fig, ax = plt.subplots(figsize=(12, 6))
eu_platform_pivot_table_combined['eu_sales'].plot(kind='pie', labels=eu_platform_pivot_table_combined.index,\
                                                  autopct='%1.1f%%', colors=sns.color_palette('viridis'))
ax.set_title('Соотношение продаж по платформам в Европе')
plt.show()

print('Топ-5 платформ по продажам в Европе')
display(eu_platform_pivot_table.head())
print()
print('Общее число продаж в Европе')
display(eu_platform_pivot_table.sum())

# %% [markdown]
# Создим сводную таблицу для суммарных продаж в Японии для каждой платформы. Выведем топ-5 платформ, остальные объеденим. Построим круговую диаграмму по полученным данным.

# %%
# Заведем сводную таблицу для суммарных продаж. 
jp_platform_pivot_table = pd.pivot_table(actual_period_data, index='platform', values='jp_sales', aggfunc='sum')\
                            .sort_values('jp_sales', ascending=False)

# Из полученной сводной таблицы вычислим продажи для "остальных" платформ.
jp_other_sales = jp_platform_pivot_table['jp_sales'][-5:].sum()

# Используем метод .copy() для работы с копией jp_platform_pivot_table.
jp_platform_pivot_table_combined = jp_platform_pivot_table[:-5].copy()  
jp_platform_pivot_table_combined.loc['Остальные'] = jp_other_sales

# Построим круговую диаграмму по полученным данным.
fig, ax = plt.subplots(figsize=(12, 6))
jp_platform_pivot_table_combined['jp_sales'].plot(kind='pie', labels=jp_platform_pivot_table_combined.index,\
                                                  autopct='%1.1f%%', colors=sns.color_palette('viridis'))
ax.set_title('Соотношение продаж по платформам в Японии')
plt.show()

print('Топ-5 платформ по продажам в Японии')
display(jp_platform_pivot_table.head())
print()
print('Общее число продаж в Японии')
display(jp_platform_pivot_table.sum())

# %% [markdown]
# **На основании построенных круговых диаграмм можем сравнить популярность платформ по следующим регионам (NA, EU, JP):**
#
#  - Лидирующие платформы в Северной Америке
#      - Общее число продаж - 284.06 млн.
#      - PS4 - 34.7% (98.61 млн)
#      - XOne - 28.6% (81.27 млн)
#
#
#  - Лидирующие платформы в Европе
#      - Общее число продаж - 270.68 млн.
#      - PS4 - 48% (130.04 млн)
#      - XOne - 17.1% (46.25 млн)
#
#
#  - Лидирующие платформы в Японии
#      - Общее число продаж - 93.09 млн.
#      - 3DS	 48% (44.24 млн)
#      - PS4	 17.1% (15.02 млн)
#
# В целом, можно отметить что североамериканскую и европейской аудиторию приходится большая часть продаж,  предпочтения в платформах у североамериканской и европейской аудитории схожи - в лидерах PS4 и XOne. На Японию приходится значительно меньшее количество продаж, аудитория предпочитает 3DS, а XOne не входит даже в топ-5.

# %% [markdown]
# **Определим самые популярные жанры каждого региона отдельно (NA, EU, JP). Опишем различия в долях продаж.**

# %% [markdown]
# Создим сводную таблицу для суммарных продаж в NA для каждого жанра. Выведем топ-5 жанров, остальные объеденим. Построим круговую диаграмму по полученным данным.

# %%
# Заведем сводную таблицу для суммарных продаж. 
na_genre_pivot_table = pd.pivot_table(actual_period_data, index='genre', values='na_sales', aggfunc='sum')\
                         .sort_values('na_sales', ascending=False)

# Из полученной сводной таблицы вычислим продажи для "остальных" жанров.
na_other_genres = na_genre_pivot_table['na_sales'][-7:].sum()

# Используем метод .copy() для работы с копией na_platform_pivot_table.
na_genre_pivot_table_combined = na_genre_pivot_table[:-7].copy()  
na_genre_pivot_table_combined.loc['Остальные'] = na_other_genres

# Построим круговую диаграмму по полученным данным.
fig, ax = plt.subplots(figsize=(12, 6))
na_genre_pivot_table_combined['na_sales'].plot(kind='pie', labels=na_genre_pivot_table_combined.index,\
                                               autopct='%1.1f%%', colors=sns.color_palette('plasma'))
ax.set_title('Соотношение жанров по платформам в Северной Америке')
plt.show()

print('Топ-5 жанров по продажам в Северной Америке')
na_genre_pivot_table.head()

# %%
# Заведем сводную таблицу для суммарных продаж. 
eu_genre_pivot_table = pd.pivot_table(actual_period_data, index='genre', values='eu_sales', aggfunc='sum')\
                         .sort_values('eu_sales', ascending=False)

# Из полученной сводной таблицы вычислим продажи для "остальных" жанров.
eu_other_genres = eu_genre_pivot_table['eu_sales'][-7:].sum()

# Используем метод .copy() для работы с копией na_platform_pivot_table.
eu_genre_pivot_table_combined = eu_genre_pivot_table[:-7].copy()  
eu_genre_pivot_table_combined.loc['Остальные'] = eu_other_genres

# Построим круговую диаграмму по полученным данным.
fig, ax = plt.subplots(figsize=(12, 6))
eu_genre_pivot_table_combined['eu_sales'].plot(kind='pie', labels=na_genre_pivot_table_combined.index,\
                                               autopct='%1.1f%%', colors=sns.color_palette('plasma'))
ax.set_title('Соотношение жанров по платформам в Европе')
plt.show()

print('Топ-5 жанров по продажам в Европе')
eu_genre_pivot_table.head()

# %%
# Заведем сводную таблицу для суммарных продаж. 
jp_genre_pivot_table = pd.pivot_table(actual_period_data, index='genre', values='jp_sales', aggfunc='sum')\
                         .sort_values('jp_sales', ascending=False)

# Из полученной сводной таблицы вычислим продажи для "остальных" жанров.
jp_other_genres = jp_genre_pivot_table['jp_sales'][-7:].sum()

# Используем метод .copy() для работы с копией jp_platform_pivot_table.
jp_genre_pivot_table_combined = jp_genre_pivot_table[:-7].copy()  
jp_genre_pivot_table_combined.loc['Остальные'] = jp_other_genres

# Построим круговую диаграмму по полученным данным.
fig, ax = plt.subplots(figsize=(12, 6))
jp_genre_pivot_table_combined['jp_sales'].plot(kind='pie', labels=jp_genre_pivot_table_combined.index,\
                                               autopct='%1.1f%%', colors = sns.color_palette('plasma'))
ax.set_title('Соотношение жанров по платформам в Японии')
plt.show()

print('Топ-5 жанров по продажам в Японии')
jp_genre_pivot_table.head()

# %% [markdown]
# **На основании построенных круговых диаграмм можем сравнить популярность жанров в следующих регионах (NA, EU, JP):**
#
#  - Лидирующие жанры в Северной Америке
#      - Shooter	27.8% (79.02 млн)
#      - Action	25.5% (72.53 млн)
#
#
#  - Лидирующие жанры в Европе
#
#      - Action	27.6% (74.68 млн)
#      - Shooter	24.2% (65.52 млн)
#
#
#  - Лидирующие жанры в Японии
#      - Role-Playing 33.5% (31.16 млн)
#      - Action 31.8% (29.58 млн)
#
# В целом, можно отметить что предпочтения в жанрах у североамериканской и европейской аудитории схожи - в лидерах Shooter и Action. В Японии, аудитория также предпочитает жанр Action, однако жанр Shooter здесь не популярен, лидером является Role-Playing.

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# В этих 2х подразделах всё отлично! Предпочтения геймеров 3х регионов в отношении игровых платформ и жанров определены. Ну и выводы соответственно описывают эти отличия.</div>

# %% [markdown]
# **Определим определим влияние ESRB рейтига на продажы каждого региона отдельно (NA, EU, JP). Опишем различия в долях продаж.**

# %% [markdown]
# Создим сводную таблицу для суммарных продаж в NA для каждого рейтинга. Построим круговую диаграмму по полученным данным.

# %%
# Заведем сводную таблицу для суммарных продаж. 
na_rating_pivot_table = pd.pivot_table(actual_period_data, index='rating', values='na_sales', aggfunc='sum')\
                          .sort_values('na_sales', ascending=False)

# Построим круговую диаграмму по полученным данным.
fig, ax = plt.subplots(figsize=(12, 6))
na_rating_pivot_table['na_sales'].plot(kind='pie', labels=na_rating_pivot_table.index,\
                                       autopct='%1.1f%%', colors=sns.color_palette('inferno_r'))
ax.set_title('Соотношение жанров по платформам в Северной Америке')
plt.show()

print('Суммарные продажи по рейтингам в Северной Америке')
na_rating_pivot_table

# %%
# Заведем сводную таблицу для суммарных продаж. 
eu_rating_pivot_table = pd.pivot_table(actual_period_data, index='rating', values='eu_sales', aggfunc='sum')\
                          .sort_values('eu_sales', ascending=False)

# Построим круговую диаграмму по полученным данным.
fig, ax = plt.subplots(figsize=(12, 6))
eu_rating_pivot_table['eu_sales'].plot(kind='pie', labels=na_rating_pivot_table.index,\
                                       autopct='%1.1f%%', colors=sns.color_palette('inferno_r'))
ax.set_title('Соотношение жанров по платформам в Европе')
plt.show()

print('Суммарные продажи по рейтингам в Европе')
eu_rating_pivot_table

# %%
# Заведем сводную таблицу для суммарных продаж. 
jp_rating_pivot_table = pd.pivot_table(actual_period_data, index='rating', values='jp_sales', aggfunc='sum')\
                          .sort_values('jp_sales', ascending=False)

# Построим круговую диаграмму по полученным данным.
fig, ax = plt.subplots(figsize=(12, 6))
jp_rating_pivot_table['jp_sales'].plot(kind='pie', labels=jp_rating_pivot_table.index,\
                                       autopct='%1.1f%%', colors = sns.color_palette('inferno_r'))
ax.set_title('Соотношение жанров по платформам в Японии')
plt.show()

print('Суммарные продажи по рейтингам в Японии')
jp_rating_pivot_table

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Один из подводных камней этого проекта. Суть его в том, что часто коллеги в самом начале «тетрадки» пропуски в 'rating' не обрабатывают, оставляют NaN, и соответственно во время анализа и/или построении графиков игры без рейтингов «теряются». Но у тебя здесь всё отлично.</div>

# %% [markdown]
# **На основании построенных круговых диаграмм можем сравнить популярность игр с определенным возростным рейтингом в следующих регионах (NA, EU, JP):**
#
#  - Наиболее распространенные рейтинги игр в Северной Америке
#      - M 33.9%	(96.42 млн)
#      - unknown 22.8% (64.72 млн)
#
#
#  - Наиболее распространенные рейтинги игр в Европе
#
#      - M 34.5%	 (93.44 млн)
#      - unknown 21.8% (58.95 млн)
#
#
#  - Наиболее распространенные рейтинги игр в Японии
#      - unknown	61.1% (56.90 млн)
#      - T 15.1% (14.78 млн)
#
# В целом, можно отметить что для североамериканского и европейского рынка наиболее распространенные рейтинги совпадают, это рейтинг M (для лиц старше 17 лет), затем идут игры с неуказанным рейтингом (unknown). На японском рынке игры с неуказанным рейтингом (unknown) лидируют, затем идут игры с рейтингом T (для подростков от 13 лет и старше). Исходя из этого можно сделать вывод о том, что западная аудитория, в сравнении с японской, как правило, более взрослая. В Японии же предпочитают игры, которые могут не подпадать под рейтинг ESRB.

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Да, верно! Рейтинг ESRB - это американский рейтинг, а в Японии есть своё рейтинговое агентство (CERO). Получается, что Япония страна со своим менталитетом. И твой анализ показывает, что Японцы в игры-то играют не такие, как весь прочий мир и жанры игр там популярны совсем другие, нежели в остальном мире, да и на рейтинги (не своего агентства) не очень то внимание обращают.</div>

# %% [markdown]
# ### Шаг 5. Проверка гипотез

# %% [markdown]
# **Равны ли средние пользовательские рейтинги платформ Xbox One и PC?**
#
# Сформулируем, и выдвинем следующие гипотезы:
# - **H0:**  Средний пользовательский рейтинг платформы Xbox One равен среднему пользовательскому рейтингу платформы PC.
# - **H1:**  Средний пользовательский рейтинг платформы Xbox One не равен среднему пользовательскому рейтингу платформы PC.

# %% [markdown]
# Выберем классический вариант задания гипотез. В данном случае мы имеем дело с двусторонней гипотезой о равенстве средних двух выборок. Проведем двухвыборочный (two-sided) t-тест для данных выборок. Считаем, что дисперсии выборок не равны, поэтому equal_var=False. После проведения данного t-теста, после сравнения p-value с установленным уровнем значимости, мы сможем сделать выводы об отвержении или неотвержении нулевой гипотезы.

# %%
alpha = 0.05  # задаем уровень стат. значимости

# Определим среднее для каждой выборки. 
pc_mean = actual_period_data.query("platform == 'PC' and user_score > -1")["user_score"].mean()
xone_mean = actual_period_data.query("platform == 'XOne' and user_score > -1")["user_score"].mean()
print(f'Среднее первой выборки: {pc_mean}')
print(f'Среднее второй выборки: {xone_mean}')
# Предварительно сгруппируем значения значения пользовательского рейтинга в зависимости от платформы.
# Проводим стат. тест о равенстве пользовательских рейтингов платформ Xbox One и PC.
results = st.ttest_ind(actual_period_data[actual_period_data['platform'] == 'PC'].query('user_score > -1')['user_score'],\
                       actual_period_data[actual_period_data['platform'] == 'XOne'].query('user_score > -1')['user_score'],\
                       alternative='two-sided')

# Выводим на экран получившееся p-значение и сравниваем с уровнем стат. значимости.
print('p-значение:', results.pvalue)

if (results.pvalue < alpha):
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Очень хорошо, что ты не забываешь отфильтровать «заглушки».
#
# Верно то, что мы используем здесь двусторонний тест.
#
# Ну и отлично, что ты понимаешь, что нельзя сделать вывод, что тест "подтвердил" одну из гипотез (в статистике гипотезы подтвердить невозможно) или "подтвердил" равенство/неравенство (можно говорить только о статистически (не)значимом различии). Например, так: «У нас нет оснований утверждать, что средние пользовательские рейтинги платформ Xbox One и PC значимо различаются».
#
# И ещё на эту же тему: никакие экспериментально полученные данные никогда не подтвердят какую-либо гипотезу. Это наше фундаментальное ограничение. Данные могут лишь не противоречить ей или, наоборот, показывать крайне маловероятные результаты (при условии, что гипотеза верна). Но и в том, и в другом случае нет оснований утверждать, что выдвинутая гипотеза доказана. Допустим, данные гипотезе не противоречат, тогда мы её не отвергаем. Если же мы приходим к выводу, что получить такие данные в рамках этой гипотезы вряд ли возможно, у нас появляется основание отбросить эту гипотезу.
#
# Статья на эту тему: https://allatambov.github.io/psms/pdf/hypo-test.pdf
# </div>

# %% [markdown]
# На основании полученных результатов можно отвергнуть нулевую гипотезу H0, так как на основании проведенного t-теста мы можем наблюдать, что средний пользовательский рейтинг платформы Xbox One практически равен среднему пользовательскому рейтингу платформы PC, при установленном уровне значимости (alpha = 0.05).

# %% [markdown]
# **Отличаются ли пользовательские рейтинги жанров Action и Sports?**
#
# Сформулируем, и выдвинем следующие гипотезы, заменив условие на обратное:
#
# - **H0:**  Средний пользовательский рейтинг жанра Action равен среднему пользовательскому рейтингу жанра Sports.
# - **H1:**  Средний пользовательский рейтинг жанра Action не равен среднему пользовательскому рейтингу жанра Sports.

# %% [markdown]
# В данном случае, выберем классический вариант задания гипотез, просто поменяв их местами для удобства. В данном случае мы имеем дело с двусторонней гипотезой о равенстве средних двух выборок. Проведем двухвыборочный (two-sided) t-тест для данных выборок. Считаем, что дисперсии выборок не равны, поэтому equal_var=False. После проведения данного t-теста, после сравнения p-value с установленным уровнем значимости, мы сможем сделать выводы об отвержении или неотвержении нулевой гипотезы.

# %%
alpha = 0.05  # задаем уровень стат. значимости

# Определим среднее для каждой выборки. 
action_mean = np.mean(actual_period_data[actual_period_data["genre"] == "Action"].query("user_score > -1")["user_score"])
sports_mean = np.mean(actual_period_data[actual_period_data["genre"] == "Sports"].query("user_score > -1")["user_score"])
print(f'Среднее первой выборки: {action_mean}')
print(f'Среднее второй выборки: {sports_mean}')

# Предварительно сгруппируем значения значения пользовательского рейтинга в зависимости от платформы.
# Проводим стат. тест о равенстве пользовательских рейтингов платформ Xbox One и PC.
results = st.ttest_ind(actual_period_data[actual_period_data['genre'] == 'Action'].query('user_score > -1')['user_score'],\
                       actual_period_data[actual_period_data['genre'] == 'Sports'].query('user_score > -1')['user_score'],\
                       alternative='two-sided')

# Выводим на экран получившееся p-значение и сравниваем с уровнем стат. значимости.
print('p-значение:', results.pvalue)

if (results.pvalue < alpha):
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')

# %% [markdown]
# На основании полученных результатов можно отвергнуть нулевую гипотезу H0, так как на основании проведенного t-теста мы можем наблюдать, средний пользовательский рейтинг жанра Action не равен среднему пользовательскому рейтингу жанра Sports, при установленном уровне значимости (alpha = 0.05).

# %% [markdown]
# **На основании проведенного анализа были выявлены определяющие успешность игры закономерности и сформулированы рекомендации, позволяющие сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.**
#
# Для прогноза продаж на 2017 год оптимально брать данные за последние **3 года (2014-2016)**, так как на игровую индустрию влияет множество факторов и рынок быстро меняется, а нам необходимо определить тренд для успешного планирования рекламных кампаний.
#
# - В целях увеличения прибыли интернет магазина при работе с североамериканской и европейской аудиторией, следует отдавать предпочтение следующим платформам: **PS4** и **XOne**.
#
# - В жанрах следует акцентировать внимание на **Shooter** и **Action**.
#
# - Пользовательские оценки и оценки критиков имеют прямую, средне-слабую корреляцию с суммарными продажами в данном регионе и их не стоит выделять как главный фактор при планировании рекламных кампаний.
#
# - Оптимальным выбором для продаж на данном рынке будет **рейтинг M** (для лиц старше 17 лет).
#
# Анализ показывает, что в Японии наблюдаются отличные от западных тенденций в игровой индустрии. Аудитория отдает предпочтение другим платформам, жанрам, имеют собственную специфику в выставлении оценок играм и.т.д. Поэтому стоит обратить особое внимание при планировании рекламных кампаний в данном регионе.
#
# - При работе с японским рынком следует отдавать предпочтение платформе **3DS**.
#
# - В жанрах следует акцентировать внимание на **Role-Playing** и **Action**.
#
# - Пользовательские оценки и оценки критиков имеют прямую, средне-слабую корреляцию с суммарными продажами в данном регионе и их не стоит выделять как главный фактор при планировании рекламных кампаний.
#
# - В данном регионе практически не обращают внимание на рейтинги ESRB (не своего агентства), поэтому в нашем анализе японском рынке игры с неуказанным рейтингом (unknown) лидируют. В рамках ESRB в данном регионе стоит отдавать предпочтение **рейтингу T** (для подростков от 13 лет и старше), так как японская аудитория, в сравнении с западной, как правило, более молодая.

# %% [markdown]
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# Самое главное - нам, нашей компании "Стримчик"-то что делать? Мы не разработчики, мы не критики, мы обычные продавцы. Нам нужно спланировать рекламную компанию на 2017 год. На что мы должны ставку делать? На что в каждом из рассмотренных регионов? Конкретика нужна от тебя, как от аналитика.
#
# Другими словами, в нашем исследовании мы проанализировали игры «с разных точек зрения». Логично, что рекламный отдел от нас ждет на какие платформы (1-2 штуки, на большее у нас не хватит рекламного бюджета), с каким жанром, с каким рейтингом ESRB и в каком регионе рекламировать. Стоит ли обращать внимание на отзывы или нет. К финальному выводу вся эта информация у нас уже есть, надо просто акцентировать на какие игры тратить рекламный бюджет.</div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Представил рекомендации в корректном виде.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Спасибо за качественный, детальный, структурированный финальный вывод! Отдельное спасибо – за **рекомендации аналитика**, которые должны помочь менеджменту компании «Стримчик» в определении потенциально выигрышных в 2017 году продуктов и проектов.
# </div>

# %% [markdown]
# # Результат ревью:
#
# Я отмечаю адекватный уровень твоей программистской подготовки. Ты используешь продвинутые концепции языка Python и библиотеки pandas. Это показывает твой уровень владения инструментами.
#
# Ты умело применяешь графические библиотеки (matplotlib / seaborn), выбираешь для визуализации ровно те типы графиков, которые нужны. Очень хорошо, что оси на графиках (в большинстве графиков!) подписаны и сами они имеют понятные названия.
#
# С комментированием никаких проблем нет. Твоих объяснений достаточно для понимания твоими коллегами хода мыслей. Ссылки из брифа проекта в нужных местах также помогают следовать за развитием событий и дают полную информацию касаемо того, что будет происходить в том или ином разделе проекта.
#
# Мне было просто проверять твой проект, потому что он чётко структурирован, с использованием оглавления.
#
# Зелёным цветом я отметил и прокомментировал удачные и элегантные решения, на которые ты можешь опираться в будущих проектах.
#
# Жёлтым цветом я выделил то, что в следующий раз можно сделать по-другому. Ты можешь учесть эти комментарии при выполнении будущих заданий или доработать проект сейчас.
#
# Однако есть принципиальные моменты, которые не позволяют мне принять твой проект в его нынешнем состоянии:
#
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# 1. В реальных рабочих датасетах скорее всего не будет полных дубликатов, но вот неявные наверняка будут встречаться, соответственно с ними надо будет уметь работать. Попробуй найти неявные дубликаты (нужно использовать параметр subset). Ну а в нашем учебном проекте пробуй найти дубликаты для пары "Имя - Игровая консоль". Как их планируешь и планируешь ли обрабатывать?
#
# 2. Одна из задач этого проекта (согласно брифа): 1. Объясните, почему заполнили пропуски определённым образом или почему не стали это делать, 2. Опишите причины, которые могли привести к пропускам 3. Обратите внимание на аббревиатуру 'tbd' в столбце с оценкой пользователей. Отдельно разберите это значение и опишите, как его обработать. Нужен твой комментарий, касающийся природы пропусков в столбце с рейтингами, а именно, может ли быть какая-то связь с тем, что в столбце с рейтингами >40% пропусков и тем, что эти оценки (рейтинги) выставляет **именно Американское рейтинговое агентство**?
#
# 3. В разделе построения «ящика с усами» по глобальным продажам игр в разбивке по платформам необходимо построить график так, чтобы квартили соответствующих «ящиков» позволяли визуально сравнивать платформы между собой. **Все боксплоты** нужно построить на одном графике.
#
# 4. В разделе расчета корреляций между оценками экспертов и продажами, «на расчет» передаются данные, содержащие «заглушки» (заполненные руками значения).
#
# 5. Формулировать, что коэффициент (линейной) корреляции (Пирсона) между 2 переменными (в нашем случае между "продажами" и "оценками") есть показатель **влияния оценок на количество продаж** - неверно.
#
# 6. Финальный вывод в таком виде - это не то, что менеджмент компании ждет от аналитика данных. Профессионал должен предоставить точные, четкие, полные и корректные **прогнозы и рекомендации**, которые помогут компании победить в конкурентной борьбе на высоко конкурентном рынке продаж компьютерных игр. Вывод же, завершающий твой рабочий проект, увы, бесполезен для генерального директора твоей компании. Он ему ничем не поможет. Здесь, в финальном выводе требуется максимально подробно описать что ты предлагаешь сделать в 2017 году, для того, чтобы твоя компания победила конкурентов.
# </div>
#
# Эти 6 моментов требуют твоего внимания. Комментарии по ним помечены красным цветом.
#
# Подводя итог: хорошая работа на самом-то деле, молодец! Есть несколько моментов к исправлению, но уверен, что они не вызовут у тебя сложностей. После доработки обязательно проверь комментарии и выводы. Их нужно будет скорректировать. Жду доработанную версию проекта на повторное ревью.

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br> Вроде бы все комментарии, помеченые красным исправил.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Да Матвей, подтверждаю - всё поправлено! Был рад работать с тобой совместно над проектом! ПРОЕКТ ПРИНЯТ!
#
# p.s. загляни сейчас в эл/почтовый ящик ...
# </div>
